# %% [markdown]
# ### Donald Bango
# ### Dr. Letort
# ### DSC 570 - Data Mining
# ### Benchmark – Strategic Alliances
# ### 23 October 2024

# %% [markdown]
# ## Assignment Objective:
# The objective of this assignment is to identify, given a network of relationships among corporations, all relationships, subgroups, influencers, alliances, and paths to follow in the pursuit of new business relationships. You will analyze a network, which depicts various types of inter-organization relationships among a large set of companies. Your task is to detect potential for alliances, the impact of interlocking boards, and then attempt to identify strategic opportunities and challenges.

# %%
# Necessary Libraries
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Load in dataset or Generate the Synthetic dataset

# %%
# Set random seed for reproducibility
np.random.seed(12)

# Generate a 20x20 matrix with random 0s and 1s
matrix_size = 20
synthetic_matrix = np.random.randint(2, size=(matrix_size, matrix_size))

# Make the matrix symmetric (ties are bidirectional)
synthetic_matrix = np.triu(synthetic_matrix) + np.triu(synthetic_matrix, 1).T

# Set the diagonal to 0 (no self-loops)
np.fill_diagonal(synthetic_matrix, 0)

# Create company labels
companies = [f'Company_{i+1}' for i in range(matrix_size)]

# Convert to DataFrame
financial_ties_df = pd.DataFrame(synthetic_matrix, index=companies, columns=companies)

# Save the matrix to an Excel file
#financial_ties_df.to_excel('FinancialTies_Synthetic.xlsx')

# Display the DataFrame
print(financial_ties_df.head())
# Out:
#            Company_1  Company_2  Company_3  Company_4  Company_5  Company_6  \
# Company_1          0          1          0          0          0          1
# Company_2          1          0          1          1          1          1
# Company_3          0          1          0          1          1          1
# Company_4          0          1          1          0          0          1
# Company_5          0          1          1          0          0          0
#
#            Company_7  Company_8  Company_9  Company_10  Company_11  \
# Company_1          0          0          0           1           0
# Company_2          1          1          1           1           0
# Company_3          1          0          1           1           0
# Company_4          1          0          1           1           1
# Company_5          1          0          1           1           1
#
#            Company_12  Company_13  Company_14  Company_15  Company_16  \
# ...

# %% [markdown]
# ### 1. Create a matrix representation of the network.

# %%
# Load the synthetic dataset from the Excel file
financial_ties_df = pd.read_excel('FinancialTies_Synthetic.xlsx', index_col=0)

# Create a NetworkX graph from the adjacency matrix
G = nx.from_pandas_adjacency(financial_ties_df)

# Print graph information
num_nodes = G.number_of_nodes()
num_edges = G.number_of_edges()
density = nx.density(G)

print(f"Graph with {num_nodes} nodes and {num_edges} edges")
print(f"Density of the Network: {density:.4f}")

# Degree of each node
print("\nDegree of each node:")
for node, degree in G.degree():
    print(f'{node}: Degree {degree}')

# Check if the graph is connected
is_connected = nx.is_connected(G)
print(f"\nIs the graph connected? {is_connected}")
# Out:
# Graph with 20 nodes and 96 edges
# Density of the Network: 0.5053
#
# Degree of each node:
# Company_1: Degree 7
# Company_2: Degree 13
# Company_3: Degree 11
# Company_4: Degree 13
# Company_5: Degree 14
# Company_6: Degree 13
# Company_7: Degree 8
# Company_8: Degree 6
# Company_9: Degree 11
# Company_10: Degree 11
# Company_11: Degree 7
# Company_12: Degree 10
# Company_13: Degree 6
# Company_14: Degree 10
# Company_15: Degree 8
# Company_16: Degree 11
# Company_17: Degree 11
# Company_18: Degree 9
# Company_19: Degree 6
# Company_20: Degree 7
#
# Is the graph connected? True

# %% [markdown]
# The graph shows 20 companies with 96 connections and a density of 0.5053, indicating a moderately connected network. Company_5 has the highest degree (14), suggesting strong integration. The graph is connected, meaning there are no isolated entities, allowing for potential influence throughout the network.

# %% [markdown]
# ### 2. Perform initial descriptive statistics analysis, calculating the following:
# - Analyze the matrix to detect potential for alliances.
# - Explain what your basis is for establishing the potential for alliances.

# %%
# Descriptive Statistics
num_nodes = G.number_of_nodes()
num_edges = G.number_of_edges()
density = nx.density(G)

print(f"Number of Nodes: {num_nodes}")
print(f"Number of Edges: {num_edges}")
print(f"Density of the Network: {density:.4f}")

# Degree Centrality
degree_centrality = nx.degree_centrality(G)

# Sort companies by degree centrality (descending order)
sorted_degree = sorted(degree_centrality.items(), key=lambda x: x[1], reverse=True)

# Print top 5 companies by degree centrality
print("\nTop 5 Companies by Degree Centrality:")
for company, centrality in sorted_degree[:5]:
    print(f"{company}: {centrality:.4f}")
# Out:
# Number of Nodes: 20
# Number of Edges: 96
# Density of the Network: 0.5053
#
# Top 5 Companies by Degree Centrality:
# Company_5: 0.7368
# Company_2: 0.6842
# Company_4: 0.6842
# Company_6: 0.6842
# Company_3: 0.5789

# %% [markdown]
# The network analysis reveals 20 companies with 96 financial ties, giving a density of 0.5053, suggesting moderate connectivity and potential for alliances.
#
# The top companies by degree centrality include Company_5 (0.7368), Company_2 (0.6842), Company_4 (0.6842), Company_6 (0.6842), and Company_3 (0.5789). These companies have the highest number of connections, indicating strong network presence and access to resources.
#
# Potential for alliances exists among companies with high degree centrality, as they are well-positioned to collaborate and bridge others in the network. The density score indicates that many companies are already connected, but opportunities remain for expanding ties with companies not yet directly linked. Strong central actors can leverage their connections to form new alliances, increasing influence and access to resources.

# %% [markdown]
# ### 3. Pick two actors that you have identified as potential allies and perform the following:
# - Generate the corresponding egocentric graphs.
# - Calculate the density of each egocentric graph.
# - Calculate the centrality of each actor.
# - For each actor (ego), compare its density and centrality.
# - Calculate the betweenness centrality of each actor.
# - Calculate the closeness centrality of each actor.
# - Calculate the prestige of each actor.
#
# We use Company_5 and Company_2 based on their high degree centrality.
#
# Egocentric Graph: Shows a company’s direct connections.
# Density: Measures how tightly the connected companies are linked to each other.
# Degree Centrality: Number of direct connections the company has.
# Betweenness Centrality: Measures how often the company acts as a bridge between others.
# Closeness Centrality: How easily the company can reach others in the network.
# Prestige (Eigenvector Centrality): A measure of influence, taking into account the influence of connected nodes.

# %%
# Plot the egocentric graph for Company_5 using draw_networkx
plt.figure(figsize=(6, 6))
pos_5 = nx.spring_layout(ego_5)  # Use a spring layout for better visualization
nx.draw_networkx(ego_5, pos=pos_5, with_labels=True, node_color='lightblue', edge_color='gray')
plt.title("Egocentric Graph of Company_5")
plt.show()

# Plot the egocentric graph for Company_2 using draw_networkx
plt.figure(figsize=(6, 6))
pos_2 = nx.spring_layout(ego_2)
nx.draw_networkx(ego_2, pos=pos_2, with_labels=True, node_color='lightgreen', edge_color='gray')
plt.title("Egocentric Graph of Company_2")
plt.show()

# %%
# Calculate and print the density of each egocentric graph
density_5 = nx.density(ego_5)
density_2 = nx.density(ego_2)

print(f"Density of Company_5's Egocentric Graph: {density_5:.4f}")
print(f"Density of Company_2's Egocentric Graph: {density_2:.4f}")
# Out:
# Density of Company_5's Egocentric Graph: 0.5238
# Density of Company_2's Egocentric Graph: 0.5604

# %%
# Calculate degree centrality for Company_5 and Company_2
degree_centrality_5 = nx.degree_centrality(G)['Company_5']
degree_centrality_2 = nx.degree_centrality(G)['Company_2']

print(f"Degree Centrality of Company_5: {degree_centrality_5:.4f}")
print(f"Degree Centrality of Company_2: {degree_centrality_2:.4f}")
# Out:
# Degree Centrality of Company_5: 0.7368
# Degree Centrality of Company_2: 0.6842

# %%
# Compare density and centrality for both actors
print("\nComparison of Density and Degree Centrality:")
print(f"Company_5 - Density: {density_5:.4f}, Degree Centrality: {degree_centrality_5:.4f}")
print(f"Company_2 - Density: {density_2:.4f}, Degree Centrality: {degree_centrality_2:.4f}")
# Out:
# Comparison of Density and Degree Centrality:
# Company_5 - Density: 0.5238, Degree Centrality: 0.7368
# Company_2 - Density: 0.5604, Degree Centrality: 0.6842

# %%
# Calculate betweenness centrality
betweenness_centrality = nx.betweenness_centrality(G)

betweenness_5 = betweenness_centrality['Company_5']
betweenness_2 = betweenness_centrality['Company_2']

print(f"Betweenness Centrality of Company_5: {betweenness_5:.4f}")
print(f"Betweenness Centrality of Company_2: {betweenness_2:.4f}")
# Out:
# Betweenness Centrality of Company_5: 0.0728
# Betweenness Centrality of Company_2: 0.0542

# %%
# Calculate closeness centrality
closeness_5 = nx.closeness_centrality(G, 'Company_5')
closeness_2 = nx.closeness_centrality(G, 'Company_2')

print(f"Closeness Centrality of Company_5: {closeness_5:.4f}")
print(f"Closeness Centrality of Company_2: {closeness_2:.4f}")
# Out:
# Closeness Centrality of Company_5: 0.7917
# Closeness Centrality of Company_2: 0.7600

# %%
# Calculate eigenvector centrality (prestige measure)
eigenvector_centrality = nx.eigenvector_centrality(G)

prestige_5 = eigenvector_centrality['Company_5']
prestige_2 = eigenvector_centrality['Company_2']

print(f"Prestige (Eigenvector Centrality) of Company_5: {prestige_5:.4f}")
print(f"Prestige (Eigenvector Centrality) of Company_2: {prestige_2:.4f}")
# Out:
# Prestige (Eigenvector Centrality) of Company_5: 0.2959
# Prestige (Eigenvector Centrality) of Company_2: 0.2864

# %% [markdown]
# ### 4. For each of the metrics above, explain its meaning in the context of this particular graph.
#
# Density of Egocentric Graphs:
# The density of Company_5’s egocentric graph is 0.5238, while Company_2’s is 0.5604. This indicates that the local network around Company_2 is slightly more interconnected, meaning its neighbors are more likely to collaborate with one another. A higher density suggests stronger relationships within the local network, potentially leading to more cohesive alliances.
#
# Degree Centrality:
# Company_5 has a degree centrality of 0.7368, higher than Company_2’s 0.6842. This shows that Company_5 has more direct connections in the network, making it more influential in forming partnerships. A high degree centrality reflects an ability to facilitate collaborations efficiently and attract potential alliances.
#
# Betweenness Centrality:
# The betweenness centrality for Company_5 is 0.0728, while for Company_2, it is 0.0542. This indicates that Company_5 plays a more significant role as a bridge between other companies in the network. Companies with high betweenness are essential for connecting disparate groups and facilitating communication or collaborations across different areas of the network.
#
# Closeness Centrality:
# Company_5’s closeness centrality is 0.7917, compared to 0.7600 for Company_2. This means that Company_5 can reach other companies more quickly within the network. A high closeness centrality suggests the company is well-positioned to gather information and leverage opportunities effectively, given its ability to access others efficiently.
#
# Prestige (Eigenvector Centrality):
# Company_5 has an eigenvector centrality of 0.2959, slightly higher than Company_2’s 0.2864. This metric indicates that Company_5 is connected to other influential companies, increasing its importance within the network. Higher prestige suggests that the company not only holds direct connections but also benefits from indirect influence through its partners.

# %% [markdown]
# ### 5. Plot the network graph and describe the characteristics evident in the plot.

# %%
# Plot the full network graph
plt.figure(figsize=(10, 8))
pos = nx.spring_layout(G)  # Use spring layout for better spacing
nx.draw_networkx(G, pos, with_labels=True, node_color='skyblue', edge_color='gray', node_size=500, font_size=10)
plt.title("Network Graph of Financial Ties")
plt.show()

# %% [markdown]
# ## Description of the Graph Characteristics:
#
# - **Graph Structure:**
#   The network consists of 20 nodes (companies) and 96 edges (financial ties). A spring layout was used to reduce edge overlap and enhance visibility.
#
# - **Connectivity:**
#   The graph is fully connected, meaning every company is reachable, indicating no isolated entities.
#
# - **Clusters and Potential Alliances:**
#   The network displays smaller clusters of closely linked companies, suggesting potential areas for deeper partnerships or alliances.
#
# - **Key Players:**
#   Companies like Company_5 and Company_2, with numerous connections, are centrally located, indicating their importance as hubs within the network.
#
# - **Bridges between Clusters:**
#   Some companies act as bridges, connecting different clusters. These firms facilitate collaborations across markets or industries.
#
# - **Density:**
#   With a moderate density of 0.5053, the network balances connectivity and diversity, allowing room for future partnerships and alliances.
#
# - **Visualization Limitation:**
#   Since the graph contains many nodes and is represented in a 2D layout, it can be challenging to fully capture and interpret all relationships and connections without visual clutter or overlap.

# %% [markdown]
# ### 6. Analyze the matrix to identify the impact of interlocking boards.
#
# Interlocking boards occur when companies share board members or influential decision-makers, potentially aligning their strategies, forming alliances, and influencing competitive actions. We can use use centrality metrics to identify potential interlocking boards.

# %% [markdown]
# Companies with high degree centrality have many direct ties, indicating potential shared board members or high influence through connections.

# %%
# Identify top companies by degree centrality (potential interlocking boards)
top_companies_by_degree = sorted(degree_centrality.items(), key=lambda x: x[1], reverse=True)[:5]
print("Top Companies with Potential Interlocking Boards (by Degree Centrality):")
for company, centrality in top_companies_by_degree:
    print(f"{company}: {centrality:.4f}")
# Out:
# Top Companies with Potential Interlocking Boards (by Degree Centrality):
# Company_5: 0.7368
# Company_2: 0.6842
# Company_4: 0.6842
# Company_6: 0.6842
# Company_3: 0.5789

# %% [markdown]
# Company_5 and Company_2 are highly connected, suggesting they may have overlapping board members or serve as influential nodes in the network.

# %% [markdown]
# Companies with high betweenness centrality bridge separate clusters, influencing how information and decisions flow across groups.

# %%
# Identify top companies by betweenness centrality (influencing multiple groups)
top_companies_by_betweenness = sorted(nx.betweenness_centrality(G).items(), key=lambda x: x[1], reverse=True)[:5]
print("\nTop Companies with Cross-Company Influence (by Betweenness Centrality):")
for company, centrality in top_companies_by_betweenness:
    print(f"{company}: {centrality:.4f}")
# Out:
# Top Companies with Cross-Company Influence (by Betweenness Centrality):
# Company_6: 0.0782
# Company_5: 0.0728
# Company_2: 0.0542
# Company_4: 0.0476
# Company_17: 0.0474

# %% [markdown]
# Company_6 and Company_5 act as intermediaries between groups, increasing their strategic influence. These companies are critical in connecting otherwise disconnected clusters, enabling or preventing alliances.

# %% [markdown]
# **Impact of Interlocking Boards**
#
# Interlocking boards facilitate strategic alliances by aligning the interests of companies through shared board members, making it easier to establish partnerships or joint ventures. However, these overlapping decision-makers also present a risk of collusion, as they may engage in anti-competitive behavior that unfairly influences the market. Additionally, interlocking boards allow companies to shape industry trends by coordinating strategic actions, such as mergers, which provide connected companies with a competitive edge.
#
# Bipartite graphs offer another useful method for detecting interlocking boards by modeling relationships between companies and shared board members. In this structure, companies and board members form two distinct node sets, with edges representing board memberships. Projecting the bipartite graph onto a unipartite graph reveals companies that share board members, with edge weights indicating the strength of their connections. This approach complements centrality measures by uncovering governance overlaps that can influence alliances, market dynamics, and competition.

# %% [markdown]
# # Bipartite Graph to detect interlocking boards

# %% [markdown]
# ### 7. Analyze the matrix to identify strategic opportunities that would benefit entities (e.g., find a partner, create/join an alliance, prevent an alliance, access a new market, etc.).

# %% [markdown]
# Opportunities for New Alliances
# Companies with Moderate Centrality: Companies with degree centrality that is neither too high nor too low may benefit from creating new alliances. These companies are connected enough to participate in the network but have room to grow by adding more partnerships.

# %%
# Identify companies with moderate degree centrality
moderate_degree = [
    company for company, centrality in degree_centrality.items() 
    if 0.4 <= centrality < 0.6
]
print("Companies with Moderate Centrality (Potential Partners):")
print(moderate_degree)
# Out:
# Companies with Moderate Centrality (Potential Partners):
# ['Company_3', 'Company_7', 'Company_9', 'Company_10', 'Company_12', 'Company_14', 'Company_15', 'Company_16', 'Company_17', 'Company_18']

# %% [markdown]
# These companies may benefit from new alliances to strengthen their network position and grow their market presence.

# %% [markdown]
#  Identify Key Hubs for Strategic Partnerships
# High Degree and High Closeness Centrality: Companies with high values in degree centrality and closeness centrality are already influential and well-positioned to quickly access resources and information. Forming alliances with such companies could offer fast access to new markets.

# %%
# Closeness centrality for all companies in the network
closeness_centrality = nx.closeness_centrality(G)

# Print the closeness centrality values
print("Closeness Centrality for All Companies:")
for company, centrality in closeness_centrality.items():
    print(f"{company}: {centrality:.4f}")
# Out:
# Closeness Centrality for All Companies:
# Company_1: 0.6129
# Company_2: 0.7600
# Company_3: 0.7037
# Company_4: 0.7600
# Company_5: 0.7917
# Company_6: 0.7600
# Company_7: 0.6333
# Company_8: 0.5938
# Company_9: 0.7037
# Company_10: 0.7037
# Company_11: 0.6129
# Company_12: 0.6786
# Company_13: 0.5938
# Company_14: 0.6786
# Company_15: 0.6333
# Company_16: 0.7037
# Company_17: 0.7037
# Company_18: 0.6552
# Company_19: 0.5938
# Company_20: 0.6129

# %%
# Identify companies with high degree and closeness centrality
key_hubs = [
    company for company in degree_centrality 
    if degree_centrality[company] > 0.6 and closeness_centrality[company] > 0.75
]
print("\nKey Hubs for Strategic Partnerships:")
print(key_hubs)
# Out:
# Key Hubs for Strategic Partnerships:
# ['Company_2', 'Company_4', 'Company_5', 'Company_6']

# %% [markdown]
# These companies are prime targets for strategic alliances to gain footing in new markets or access needed resources.

# %% [markdown]
# Prevent Competitor Alliances
# Companies with High Betweenness Centrality: Companies acting as bridges between others can facilitate or block alliances. If competitors are linked through one of these bridging companies, forming an alliance with the bridging company could prevent unwanted collaborations.

# %%
# Identify companies with high betweenness centrality
high_betweenness = [
    company for company, centrality in betweenness_centrality.items() 
    if centrality > 0.07
]
print("\nCompanies Acting as Bridges:")
print(high_betweenness)
# Out:
# Companies Acting as Bridges (Prevent Potential Competitor Alliances):
# ['Company_5', 'Company_6']

# %% [markdown]
# Collaborating with these bridging companies can prevent competitors from accessing certain markets or gaining influence.

# %% [markdown]
# Access New Markets through Cluster Collaboration
# Cluster Detection and Collaboration: Companies identified in separate clusters can explore partnerships to access new markets. The ability to bridge clusters will create synergies that benefit both parties.

# %%
# Detect clusters using community detection (Girvan-Newman algorithm)
from networkx.algorithms.community import girvan_newman

communities = next(girvan_newman(G))
print("\nDetected Clusters:")
print([list(community) for community in communities])
# Out:
# Detected Clusters:
# [['Company_19', 'Company_13', 'Company_9', 'Company_4', 'Company_15', 'Company_12', 'Company_7', 'Company_3', 'Company_2', 'Company_10', 'Company_20', 'Company_17', 'Company_18', 'Company_1', 'Company_16', 'Company_6', 'Company_11', 'Company_14', 'Company_5'], ['Company_8']]

# %% [markdown]
# Companies from different clusters can form alliances to access markets or resources not available within their current networks.

# %% [markdown]
# ### 8. Weak and Strong Ties within the Organization
#
# #### Strong Ties
# 1. **Company_5 and Company_6**
#    - Both companies show high degree centrality and betweenness centrality, acting as key bridges in the network. These metrics reflect well-established relationships and frequent interactions, marking them as critical hubs.
#
# 2. **Company_2 and Company_4**
#    - With high closeness centrality (0.76) and strong degree centrality, these companies are positioned centrally in the network. Their high connectivity makes them reliable partners, reinforcing a strong collaborative relationship.
#
# #### Weak Ties
# 1. **Company_8 and Company_19**
#    - Company_8 is isolated from the primary cluster, and Company_19 has minimal connections, as indicated by community detection. These weak ties suggest limited collaboration, with room to form stronger alliances.
#
# 2. **Company_13 and Company_7**
#    - Both companies have moderate degree centrality, reflecting their participation in the network without dominant influence. Their ties are relatively weak, offering opportunities for strategic growth and deeper collaborations.

# %% [markdown]
# ### 9. Detect Structural Holes and Explain Their Impact on Social Closures
#
# #### Definition of Structural Holes
# A structural hole refers to a gap between companies (nodes) that are not directly connected but could benefit from collaboration. Bridging these holes allows access to non-redundant information and strategic advantages. Social closure occurs when such gaps are filled, promoting trust and cooperation, but it may also reduce innovation by limiting access to diverse partnerships.
#
# #### Identifying Structural Holes and Key Bridges
# Structural holes can be detected by identifying companies with **high betweenness centrality**, as these companies act as intermediaries between clusters.

# %%
# Calculate betweenness centrality for all companies
betweenness_centrality = nx.betweenness_centrality(G)

# Identify companies with high betweenness centrality (bridging structural holes)
structural_hole_bridges = [
    company for company, centrality in betweenness_centrality.items() 
    if centrality > 0.07  # Adjust threshold as needed based on output
]
print("Companies Bridging Structural Holes:")
print(structural_hole_bridges)

# Use community detection to find isolated groups (structural holes)
from networkx.algorithms.community import girvan_newman

communities = next(girvan_newman(G))
print("\nDetected Communities:")
for i, community in enumerate(communities):
    print(f"Community {i + 1}: {list(community)}")

# Identify isolated nodes or small clusters (structural holes)
isolated_communities = [community for community in communities if len(community) < 3]
print("\nIsolated or Small Communities (Potential Structural Holes):")
print(isolated_communities)
# Out:
# Companies Bridging Structural Holes:
# ['Company_5', 'Company_6']
#
# Detected Communities:
# Community 1: ['Company_19', 'Company_13', 'Company_9', 'Company_4', 'Company_15', 'Company_12', 'Company_7', 'Company_3', 'Company_2', 'Company_10', 'Company_20', 'Company_17', 'Company_18', 'Company_1', 'Company_16', 'Company_6', 'Company_11', 'Company_14', 'Company_5']
# Community 2: ['Company_8']
#
# Isolated or Small Communities (Potential Structural Holes):
# [{'Company_8'}]

# %% [markdown]
# **Companies Bridging Structural Holes:**
#
#
# Company_5 and Company_6 exhibit high betweenness centrality, acting as key connectors between different parts of the network. Their role allows them to bridge structural holes, facilitating collaborations and influencing the flow of information.
#
# **Detected Communities:**
#
# Community 1: A large, interconnected cluster of companies, promoting trust but with potential redundancy.
# Community 2: Company_8 stands alone as an isolated node and structural hole.
# Isolated or Small Communities (Potential Structural Holes):
# {'Company_8'} represents a structural hole, lacking integration with the main network. This gap indicates missed opportunities for collaboration or alliances, limiting Company_8's access to resources.
#
# **Impact of Structural Holes:**
#
# Opportunities: Bridging gaps can enhance collaboration and expand market access.
# Risk of Isolation: Company_8 risks exclusion from essential partnerships, weakening competitiveness.
# Social Closure: While filling gaps can improve trust, it may also lead to redundancy, limiting innovation by over-relying on the same partners.
# This analysis reveals how Company_5 and Company_6 maintain network stability by bridging gaps, while connecting isolated companies like Company_8 could unlock new opportunities for growth and collaboration.

# %% [markdown]
# ### 10. Analyze the Matrix to Identify Challenges Entities May Face
# **Unreachable Entities:**
# Company_8 is isolated in a small cluster, limiting its ability to form partnerships or access new resources within the larger network.
#
# **Overcrowded Regions (Competition):**
# Community 1, with 19 interconnected companies, reflects a dense competitive environment. Companies within this cluster may struggle to stand out or gain unique advantages due to overlapping partnerships.
#
# **High Networking Costs:**
# Companies like Company_5 and Company_6, which bridge structural holes, hold a competitive edge. Smaller companies may face high costs when trying to connect with these key players to access markets or information.
#
# **Dependency on Key Hubs:**.
# High-betweenness companies, such as Company_5 and Company_6, serve as critical connectors. Their disruption could destabilize parts of the network, creating vulnerabilities for companies dependent on them.
#
# Strategic management of connections is important to reduce dependencies, balance network density, and promote partnerships that mitigate isolation and high networking costs.

# %% [markdown]
# ### 11. Impact of Informal Networks on the Power Structure of Organizations
# Informal networks significantly shape organizational power dynamics. Companies like Company_5 and Company_6, with high betweenness centrality, act as brokers by controlling the flow of information and resources, giving them influence beyond formal structures. In densely connected clusters, such as Community 1, informal ties promote trust and collaboration, though they can also create competitive bottlenecks, making it difficult for companies to distinguish themselves. Informal alliances within these clusters offer access to new opportunities that may not be available through formal channels.
#
# However, isolated companies like Company_8 lack the advantage of these informal ties, limiting their access to resources and opportunities. This demonstrates how informal networks can either facilitate integration and influence or perpetuate inequality by concentrating power among well-connected entities. Overall, informal networks enhance collaboration and access but can also reinforce disparities by amplifying the influence of key brokers and isolating less connected companies.

# %% [markdown]
# ### 12. In-Depth Analysis of Alliances, Interlocking Boards, Strategic Opportunities, and Challenges
# **Potential for Alliances and Their Effects:**
#
# Companies with high degree and closeness centrality, such as Company_2, Company_5, and Company_6, are ideal partners for collaboration. Alliances with these companies enhance resource sharing, market access, and innovation. However, over-reliance on these key hubs introduces risks if they exit the network, creating potential disruptions.
#
# **Impact of Interlocking Boards:**
#
# Companies bridging structural holes, like Company_5 and Company_6, connect otherwise unlinked firms, giving them strategic influence over decision-making and resource flows. These informal board interlocks promote cooperation and trust but may also create bottlenecks by concentrating power in a few entities, limiting broader collaboration.
#
# **Strategic Opportunities:**
#
# Opportunities include integrating isolated nodes, such as Company_8, into the network, unlocking new business avenues. Collaborating with companies with moderate degree centrality, like Company_9 and Company_12, can improve efficiency and influence. Additionally, preventing alliances between competitors bridging structural holes can safeguard market positions.
#
# **Challenges and Risks:**
#
# Challenges include overcrowded clusters, where companies struggle to differentiate themselves. Smaller firms may also face high networking costs, limiting their access to key hubs and new markets. Isolated companies, like Company_8, require proactive engagement to avoid exclusion and build meaningful partnerships.
#
# **Conclusion:**
#
# While alliances provide growth potential, they introduce risks in managing dependencies, controlling competition, and ensuring balanced collaboration. A strategic approach is essential to leverage opportunities while mitigating risks across the network.

# %% [markdown]
# ### 13. Justification for Strategic Decisions
# The strategic decisions in this analysis are based on Social Network Analysis (SNA) metrics and align with key principles discussed throughout the course. Companies like Company_2, Company_5, and Company_6, identified through high degree and closeness centrality, are positioned as influential hubs. Partnering with these companies offers strategic advantages such as better access to resources and faster information flow (Gupta, Trivedi, & Singh, 2024). Their central roles highlight the importance of collaboration to enhance resource sharing and expand market access.
#
# Integrating isolated companies, such as Company_8, reflects the significance of bridging structural holes (Evtushenko & Gastner, 2019). Bridging these gaps not only reduces fragmentation but also unlocks new business opportunities by promoting collaboration and preventing exclusion, fostering network resilience.
#
# The identification of Company_5 and Company_6 as brokers through high betweenness centrality supports decisions aimed at preventing competitor alliances (Tlemsani et al., 2021). These companies control the flow of information and resources across clusters, and limiting competitors’ access to these key players protects market position and strategic advantages.
#
# Collaborating with moderately connected companies, such as Company_9 and Company_12, aligns with the principle of cultivating growth potential within entities that have room to expand influence. Such alliances reduce competition within overcrowded clusters and create space for innovation, promoting sustained competitive advantages (Kim, 1997).
#
# These decisions are consistent with resource dependence theory, which emphasizes leveraging interdependencies to manage risks, and game theory, which focuses on strategic collaboration for mutual benefits. This analysis combines quantitative metrics with qualitative insights, demonstrating the application of core concepts discussed throughout the course.

# %% [markdown]
# ## References
# Evtushenko, A., & Gastner, M. T. (2019). Beyond Fortune 500: Women in a global network of directors. arXiv. https://doi.org/10.48550/arXiv.1910.07441
#
# Gupta, U., Trivedi, G., & Singh, D. (2024). Human AI: Social network analysis. In Emotional AI and Human-AI Interactions in Social Networking (pp. 213-235). Elsevier. https://doi.org/10.1016/B978-0-443-19096-4.00004-3
#
# Kim, J. (1997). An empirical study of longevity of strategic alliances: An event history analysis. ETD Collection for University of Nebraska-Lincoln. https://digitalcommons.unl.edu/dissertations/AAI9734622
#
# Tlemsani, I., Hashim, M. A. M., & Matthews, R. (2021). Games theory and strategic alliances: Applications to British-Russian partnership. Higher Education, Skills and Work-Based Learning, 11(4), 853-866. https://doi.org/10.1108/HESWBL-05-2021-0092
