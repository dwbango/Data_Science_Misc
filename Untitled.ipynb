# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a directed graph
G = nx.DiGraph()

# Add edges representing relationships in a directed network
edges = [("A", "B"), ("A", "C"), 
         ("B", "D"), ("C", "D"), 
         ("D", "E"), ("C", "E")]

G.add_edges_from(edges)

# Calculate centrality measures
degree_centrality = nx.degree_centrality(G)
betweenness_centrality = nx.betweenness_centrality(G, normalized=True)
closeness_centrality = nx.closeness_centrality(G)
prestige = nx.in_degree_centrality(G)  # Using in-degree centrality as prestige

# Display the results
print("Degree Centrality:", degree_centrality)
print("Betweenness Centrality:", betweenness_centrality)
print("Closeness Centrality:", closeness_centrality)
print("Prestige (In-Degree Centrality):", prestige)

plt.figure(figsize=(8, 6))
pos = nx.spring_layout(G)
node_sizes = [v * 1000 for v in degree_centrality.values()]
nx.draw_networkx_nodes(G, pos, node_size=node_sizes, node_color='skyblue')
nx.draw_networkx_edges(G, pos, arrowstyle='->', arrowsize=20)
nx.draw_networkx_labels(G, pos, font_size=12, font_color='black')
plt.title('Directed Graph with Centrality Measures')
plt.show()
# Out:
# Degree Centrality: {'A': 0.5, 'B': 0.5, 'C': 0.75, 'D': 0.75, 'E': 0.5}
# Betweenness Centrality: {'A': 0.0, 'B': 0.041666666666666664, 'C': 0.125, 'D': 0.08333333333333333, 'E': 0.0}
# Closeness Centrality: {'A': 0.0, 'B': 0.25, 'C': 0.25, 'D': 0.5625, 'E': 0.6666666666666666}
# Prestige (In-Degree Centrality): {'A': 0.0, 'B': 0.25, 'C': 0.25, 'D': 0.5, 'E': 0.5}

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Directed graph
G = nx.DiGraph()

edges = [
    ("A", "B"), ("A", "C"), ("B", "D"), 
    ("C", "D"), ("D", "E"), ("C", "E"), 
    ("E", "F"), ("F", "G"), ("G", "H"), 
    ("H", "I"), ("I", "J"), ("J", "A"), 
    ("B", "G"), ("D", "I"), ("H", "C")
]
G.add_edges_from(edges)

# Centrality measures
degree_centrality = nx.degree_centrality(G)
betweenness_centrality = nx.betweenness_centrality(G, normalized=True)
closeness_centrality = nx.closeness_centrality(G)
prestige = nx.in_degree_centrality(G)  # In-degree centrality as prestige

# Results
print("Degree Centrality:", degree_centrality)
print("Betweenness Centrality:", betweenness_centrality)
print("Closeness Centrality:", closeness_centrality)
print("Prestige (In-Degree Centrality):", prestige)

plt.figure(figsize=(10, 8))
pos = nx.spring_layout(G, seed=42)  # Consistent layout for multiple runs

# Node sizes based on degree centrality
node_sizes = [v * 1200 for v in degree_centrality.values()]

# Node colors based on betweenness centrality
node_colors = [v for v in betweenness_centrality.values()]

# Nodes
nodes = nx.draw_networkx_nodes(G, pos, node_size=node_sizes, 
                               node_color=node_colors, cmap=plt.cm.viridis)

# Edges with directed arrows
nx.draw_networkx_edges(G, pos, arrowstyle='->', arrowsize=15, edge_color='gray')

# Label
nx.draw_networkx_labels(G, pos, font_size=12, font_color='black')

# Color bar for betweenness centrality
plt.colorbar(nodes, label="Betweenness Centrality")

# title and legend
plt.title('Advanced Directed Graph with Centrality Measures')

plt.show()
# Out:
# Degree Centrality: {'A': 0.3333333333333333, 'B': 0.3333333333333333, 'C': 0.4444444444444444, 'D': 0.4444444444444444, 'E': 0.3333333333333333, 'F': 0.2222222222222222, 'G': 0.3333333333333333, 'H': 0.3333333333333333, 'I': 0.3333333333333333, 'J': 0.2222222222222222}
# Betweenness Centrality: {'A': 0.3055555555555555, 'B': 0.125, 'C': 0.2638888888888889, 'D': 0.16666666666666666, 'E': 0.18055555555555555, 'F': 0.18055555555555555, 'G': 0.3055555555555555, 'H': 0.3055555555555555, 'I': 0.3055555555555555, 'J': 0.3055555555555555}
# Closeness Centrality: {'A': 0.28125, 'B': 0.24324324324324326, 'C': 0.391304347826087, 'D': 0.36, 'E': 0.4090909090909091, 'F': 0.3333333333333333, 'G': 0.391304347826087, 'H': 0.32142857142857145, 'I': 0.4090909090909091, 'J': 0.3333333333333333}
# ...
