# %%
# Don
# Dr. Ofori 
# 14 Oct 2023
# Topic 5 DQ 1
# YouTube Link: https://youtu.be/lcigBEZ485I

# %%
# Import libraries
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats

# %%
_=''' 
Explain the difference between correlation and causation:

# Correlation measures the linear relationship between two variables. Correlation does not imply a cause-and-effect relationship. 
The Pearson correlation coefficient (r) is a widely-used measure, ranging from -1 (perfect negative correlation) 
to 1 (perfect positive correlation) with 0 indicating no correlation at between the two variables.

# Causation denotes a direct cause-and-effect relationship. To establish this, Extensive experimentation is essential.
Controlled experiments, in particular, are crucial as they ensure that confounding and extraneous variables are effectively managed.
'''

# %%
_=''' 
Why is it important to understand the distinction between the two when interpreting statistical results? 

Misinterpreting correlation as causation can lead to false conclusions and unsound decisions based on those conclusions. 
This can be harful when used for 'informed' Decision Making Especially in fields like public policy, medicine, and business, 
decisions based on misinterpreted data can have wide spread consequences. For example, if a drug is correlated with health improvement
but is not the direct cause of it, widespread use of the drug could be ineffective at best or harmful at worst.
It is crucial for both ethical integrity and professional credibility as well. 
'''

# %%
_='''
Provide at least two examples of a correlation that does not necessarily imply causation: 

Ice Cream Sales vs. Drowning incidents
A well-known example illustrating the distinction between correlation and causation involves ice cream sales and drowning incidents. 
As summer temperatures rise, ice cream sales tend to spike due to the natural desire for cooler treats. Simultaneously, with most schools out 
of session and the warmer weather, more kids and families frequent pools, water sports, and beaches, leading to an increase in drowning 
incidents. Although there's a correlation between higher ice cream sales and increased drownings during the summer, one does not cause the 
other. Instead, the underlying factor is the seasonal shift, which influences both activities. The increased temperature is the link for
increased icecream sales and increase of water activities that holds the chance of drowning incidents.
'''

# Hypothetical Data 
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
ice_cream_sales = [30, 35, 40, 60, 70, 100, 110, 105, 75, 65, 40, 32]
drowning_incidents = [2, 2, 3, 5, 8, 12, 14, 13, 9, 6, 3, 2]

# Correlation and p - value calculation
r, p = pearsonr(ice_cream_sales, drowning_incidents)

# Plotting
plt.figure(figsize=(10,6))
plt.scatter(ice_cream_sales, drowning_incidents, color='blue', s=50)
for i, txt in enumerate(months):
    plt.annotate(txt, (ice_cream_sales[i], drowning_incidents[i]))
plt.title('Correlation between Ice Cream Sales and Drowning Incidents')
plt.xlabel('Ice Cream Sales (Thousands $)')
plt.ylabel('Drowning Incidents')
plt.grid(True)
plt.tight_layout()
plt.show()

print(f'Pearson Correlation Coefficient: {r:.2f}')
print(f'P-value: {p:.4f}')

# Test significance
alpha = 0.05  # significance level
if p < alpha:
    print(f"The correlation is statistically significant at the {alpha*100}% level.")
else:
    print(f"The correlation is not statistically significant at the {alpha*100}% level.")
# Out:
# Pearson Correlation Coefficient: 0.99
# P-value: 0.0000
# The correlation is statistically significant at the 5.0% level.

# %%
''' 
Example 2: Fingerless Glove Sales vs. Frostbitten Fingers:

Dr. Gary Fry highlighted an intuitive example of potential misinterpretation due to correlation (Fry, 2023). 
In the winter, sales of fingerless gloves see an uptick. Similarly, during these cold months, there's an increase in 
cases of frostbitten fingers. While a strong correlation might exist between the two variables, as Fry (2023) aptly 
notes, "correlation, no matter how strong, does not imply cause-effect relationships." Fingerless gloves do not cause frostbite. 
People can wear them during the summer with negligible risk of getting frostbite. The "obvious link" is the cold of winter, 
which is the primary factor behind both the increase in frostbitten fingers and the surge in fingerless glove sales (Fry, 2023).
'''

# %%
_=''' 
How can hypothesis testing be used to determine whether a correlation is statistically significant and can be used to make causal inferences?

Hypothesis testing is a foundational tool in statistics, allowing us to infer or validate claims about populations using sample data. 
When considering correlation, hypothesis testing enables us to evaluate whether an observed correlation in sample data can be extrapolated 
to the broader population. Specifically, we test the null hypothesis of no correlation against the alternative hypothesis of a non-zero 
correlation,using the p-value as a measure of the evidence against the null hypothesis. It is essential to remember, that a statistically 
significant correlation does not imply causation. Even in data science, where we often deal with vast and complex datasets, 
this fundamental caution remains crucial.
'''

# %%
# YouTube Link: https://youtu.be/lcigBEZ485I

# %%
# Reference(s): 
# Fry, G. T. (2023, January 1). CORRELATION VS. CAUSATION: Watch out for hidden links. Railway Age, 224(1), 36.
